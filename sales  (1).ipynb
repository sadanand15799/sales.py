# %% [markdown]
# #Python Pandas & Python Matplotlib to analyze and answer business questions about 7 years worth of sales data. The data contains paper,ink,printer sales

# %% [markdown]
# #We start by cleaning data. Tasks during this section include:
# *  Drop NaN values from DataFrame
# *  Removing duplicates values
# *  Removing irrelevant columns
# Once we have cleaned up our data a bit, we move the data exploration section. In this section we explore 5 high level business questions related to our data:
#
#
#
# 1.   Top 5 Customers?
# 2.   who is Best Customer And Why?
# 3.   What is profit margin per product?
# 4.   How is Business doing?
# 5.   which country sold the most product?
#
# #Process

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# loading sales file into pandas dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/upwork_task.csv')

# %%
df.head(2)
# Out:
#        Date   Customer Name                                    Product Name  \
# 0  3/3/2016  Erin Heselwood  A4 Copy Paper, 200gsm Silk Premium, 500 sheets
# 1  3/3/2016  Erin Heselwood                   Toner Cartridge, Three Colour
#
#    Line Quantity  Line Total Amount         Customer Address Customer City  \
# 0              2               53.0  826 Lotheville Junction     Krotoszyn
# 1              1              192.0  826 Lotheville Junction     Krotoszyn
#
#   Customer Country          Customer Email Customer Phone No  ...  \
# 0           Poland  eheselwood0@drupal.org      455-728-0674  ...
# 1           Poland  eheselwood0@drupal.org      455-728-0674  ...
#
#    Product Category  Product Cost  Product Price Product Quantity On Hand  \
# 0             Paper         20.05           26.5                       17
# 1               Ink         81.00          192.0                        9
#
#     Product SKU  Shipped Date     Status  Subtotal Amount Tax Amount  \
# 0  PA4-200-SILK           NaN  Completed            220.5       24.5
# 1      INK-TRIC           NaN  Completed            220.5       24.5
#
#   Total Amount
# 0        245.0
# 1        245.0
#
# [2 rows x 24 columns]

# %% [markdown]
# #Exploring ,cleaning and formatting data
# 1.Check  for duplicates values

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2.Check missing values

# %%
missing_value=df.isnull().sum()
missing_value
# Out:
# Date                          0
# Customer Name                 0
# Product Name                  0
# Line Quantity                 0
# Line Total Amount             0
# Customer Address              0
# Customer City                 0
# Customer Country              0
# Customer Email                0
# Customer Phone No             0
# Line Number                   0
# Line Tax Amount               0
# Line Unit Price               0
# Payment Method                0
# Product Category              0
# Product Cost                  0
# Product Price                 0
# Product Quantity On Hand      0
# Product SKU                   0
# Shipped Date                891
# Status                        0
# Subtotal Amount               0
# Tax Amount                    0
# Total Amount                  0
# dtype: int64

# %% [markdown]
# 3.Replacing missing values

# %%
df['Shipped Date']=df['Shipped Date'].fillna('Unknown')
df.isnull().sum()
# Out:
# Date                        0
# Customer Name               0
# Product Name                0
# Line Quantity               0
# Line Total Amount           0
# Customer Address            0
# Customer City               0
# Customer Country            0
# Customer Email              0
# Customer Phone No           0
# Line Number                 0
# Line Tax Amount             0
# Line Unit Price             0
# Payment Method              0
# Product Category            0
# Product Cost                0
# Product Price               0
# Product Quantity On Hand    0
# Product SKU                 0
# Shipped Date                0
# Status                      0
# Subtotal Amount             0
# Tax Amount                  0
# Total Amount                0
# dtype: int64

# %%
df.dtypes
# Out:
# Date                         object
# Customer Name                object
# Product Name                 object
# Line Quantity                 int64
# Line Total Amount           float64
# Customer Address             object
# Customer City                object
# Customer Country             object
# Customer Email               object
# Customer Phone No            object
# Line Number                   int64
# Line Tax Amount             float64
# Line Unit Price             float64
# Payment Method               object
# Product Category             object
# Product Cost                float64
# Product Price               float64
# Product Quantity On Hand      int64
# Product SKU                  object
# Shipped Date                 object
# Status                       object
# Subtotal Amount             float64
# Tax Amount                  float64
# Total Amount                float64
# dtype: object

# %% [markdown]
# 4.Remove irrelevant columns

# %%
df.drop(columns=['Customer Address', 'Customer Email'], inplace=True)

# %%
df.describe()
# Out:
#        Line Quantity  Line Total Amount  Line Number  Line Tax Amount  \
# count    2883.000000        2883.000000  2883.000000      2883.000000
# mean        1.197364         161.001131     1.259799        16.100694
# std         0.485279         538.505298     0.454910        53.850374
# min         1.000000           4.990000     1.000000         0.500000
# 25%         1.000000          17.990000     1.000000         1.800000
# 50%         1.000000          26.500000     1.000000         2.650000
# 75%         1.000000         162.000000     2.000000        16.200000
# max         3.000000        8400.000000     3.000000       840.000000
#
#        Line Unit Price  Product Cost  Product Price  Product Quantity On Hand  \
# count      2883.000000   2883.000000    2883.000000               2883.000000
# mean        136.735054     65.460087     136.735054                 15.075963
# std         425.568281    187.663240     425.568281                  5.498545
# min           4.990000      3.270000       4.990000                  3.000000
# 25%          17.990000      8.820000      17.990000                  9.000000
# 50%          26.500000     20.050000      26.500000                 15.000000
# 75%         162.000000     66.000000     162.000000                 17.000000
# max        2800.000000   1091.000000    2800.000000                 22.000000
#
#        Subtotal Amount   Tax Amount  Total Amount
# count      2883.000000  2883.000000   2883.000000
# mean        207.586511    23.066042    230.652553
# std         525.813041    58.423544    584.236584
# min           4.490000     0.500000      4.990000
# 25%          16.190000     1.800000     17.990000
# 50%         150.290000    16.700000    166.990000
# 75%         188.990000    21.000000    209.990000
# max        7592.380000   843.600000   8435.980000

# %% [markdown]
# 1.Top 5 Customers?

# %%
best_customer = df.groupby('Customer Name')['Total Amount'].sum().nlargest(5)
best_customer
# Out:
# Customer Name
# Viviyan Pearson      88055.32
# Hyacinthe Cammish    79240.53
# Amos Henighan        72957.27
# Kenton Slaten        70928.78
# Austin Stirtle       66325.30
# Name: Total Amount, dtype: float64

# %%
# Calculate total spend for each customer
customer_spend = df.groupby('Customer Name')['Total Amount'].sum().sort_values(ascending=False)

# Get the top 5 customers by spend
top_5_customers = customer_spend.head()

# Plot the bar chart
plt.bar(top_5_customers.index, top_5_customers.values,align="edge")
plt.title('Top 5 Customers ')
plt.xlabel('Customer Name')
plt.ylabel('Total Spend')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Best Customer And Why?

# %%
# Get the top 1 customer by spend
top_1_customer = df.groupby('Customer Name')['Total Amount'].sum().nlargest(1).index[0]

# Get the total spend for the top 1 customer by category
customer_category_spend = df.groupby(['Customer Name', 'Product Category'])['Total Amount'].sum().unstack().loc[[top_1_customer]]

# Normalize the data
customer_category_spend = customer_category_spend.div(customer_category_spend.sum(axis=1), axis=0)

# Plot the stacked bar chart
colors = plt.cm.tab20(np.linspace(0, 1, len(customer_category_spend.columns)))
customer_category_spend.plot(kind='bar', stacked=True, color=colors)
plt.title(f'{top_1_customer}\'s Spend by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Percentage of Total Spend')
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 2. What is profit margin per product

# %%
# Calculate profit margin
df['Profit Margin'] = df['Product Price'] - df['Product Cost']

# Group by product category and calculate the total profit
total_profit = df.groupby('Product Category')['Profit Margin'].sum()

# Sort by profit in descending order
total_profit = total_profit.sort_values(ascending=False)

# Plot the top 10 product categories by profit
plt.bar(total_profit.head(10).index, total_profit.head(10))
plt.xticks(rotation=0)
plt.xlabel('Product Category')
plt.ylabel('Profit (USD)')
plt.title('Top 10 Product Categories by Profit')

# Display profit amount on top of each bar
for i, v in enumerate(total_profit.head(10)):
    plt.text(i, v + 0.01, f'{v:.2f}', ha='center')

plt.show()

# %% [markdown]
# how is business doing

# %%
# convert Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# group by year and sum the Total Amount column
yearly_totals = df.groupby(df['Date'].dt.year)['Total Amount'].sum()

# create line chart
plt.plot(yearly_totals.index, yearly_totals.values)

# set x-axis label and tick marks
plt.xlabel('Year')
plt.xticks(yearly_totals.index)

# set y-axis label and format ticks as thousands
plt.ylabel('Total Amount (in thousands of Indian Rupees)')
plt.yticks(yearly_totals.values.round(-3) / 1000)

# display data labels on plot
for i, val in enumerate(yearly_totals.values):
    plt.text(yearly_totals.index[i], val, int(val / 1000), ha='center', va='bottom')

# display plot
plt.show()

# %% [markdown]
# which country sold the most product?**bold text**

# %%
import plotly.express as px
# Aggregate the sales data by country
sales_by_country = df.groupby('Customer Country').agg({'Total Amount': 'sum'}).reset_index()

# Create a choropleth map with the total sales amount by country
fig = px.choropleth(sales_by_country, 
                    locations='Customer Country', 
                    locationmode='country names',
                    color='Total Amount',
                    color_continuous_scale='Viridis',
                    title='Total Sales Amount by Country',
                    hover_name='Customer Country', hover_data={'Total Amount': ':.2f'})
                
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e6a17005-f544-4c6b-9420-8b18b83de660" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6a17005-f544-4c6b-9420-8b18b83de660")) {                    Plotly.newPlot(                        "e6a17005-f544-4c6b-9420-8b18b83de660",                        [{"coloraxis":"coloraxis","customdata":[[55034.35],[66325.3],[143886.05],[79240.53],[88055.31999999999],[62026.51],[58463.05],[63074.17],[48866.03]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Customer Country=%{location}<br>Total Amount=%{z:.2f}<extra></extra>","hovertext":["Australia","Bulgaria","China","Finland","Indonesia","Poland","Portugal","Sri Lanka","Thailand"],"locationmode":"country names","locations":["Australia","Bulgaria","China","Finland","Indonesia","Poland","Portugal","Sri Lanka","Thailand"],"name":"","z":[55034.35,66325.3,143886.05,79240.53,88055.31999999999,62026.51,58463.05,63074.17,48866.03],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh ...

# %%
# Aggregate the sales data by country
sales_by_country = df.groupby('Customer Country').agg({'Total Amount': 'sum'}).reset_index()

# Sort the data by total sales in descending order
sales_by_country = sales_by_country.sort_values(by='Total Amount', ascending=False)

# Identify the top country by sales
top_country = sales_by_country['Customer Country'].iloc[0]

# Create a bar chart to visualize the sales data by country
fig = px.bar(sales_by_country, 
             x='Customer Country', 
             y='Total Amount', 
             color='Customer Country',
             title='Sales by Country')

fig.show()

# Add additional information to the chart to identify factors contributing to high sales in the top country
sales_by_category = df[df['Customer Country'] == top_country].groupby('Product Category').agg({'Total Amount': 'sum'}).reset_index()

fig = px.bar(sales_by_category, 
             x='Product Category', 
             y='Total Amount', 
             color='Product Category',
             title=f'Sales by Product Category in {top_country}')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5e27bf0b-d583-45ce-84c8-23094ae0e56c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e27bf0b-d583-45ce-84c8-23094ae0e56c")) {                    Plotly.newPlot(                        "5e27bf0b-d583-45ce-84c8-23094ae0e56c",                        [{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"China","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[143886.05],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Indonesia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Indonesia","offsetgroup":"Indonesia","orientation":"v","showlegend":true,"textposition":"auto","x":["Indonesia"],"xaxis":"x","y":[88055.31999999999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Finland","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Finland","offsetgroup":"Finland","orientation":"v","showlegend":true,"textposition":"auto","x":["Finland"],"xaxis":"x","y":[79240.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Bulgaria","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bulgaria","offsetgroup":"Bulgaria","orientation":"v","showlegend":true,"textposition":"auto","x":["Bulgaria"],"xaxis":"x","y":[66325.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"v","showlegend":true,"textposition":"auto","x":["Sri Lanka"],"xaxis":"x","y":[63074.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Poland","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Poland","offsetgroup":"Poland","orientation":"v","showlegend":true,"textposition":"auto","x":["Poland"],"xaxis":"x","y":[62026.51],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Portugal","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Portugal","offsetgroup":"Portugal","orientation":"v","showlegend":true,"textposition":"auto","x":["Portugal"],"xaxis":"x","y":[58463.05],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[55034.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Customer Country=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Thailand","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Thailand","offsetgroup":"Thailand","orientation":"v","showlegend":true,"textposition":"auto","x":["Thailand"],"xaxis":"x","y":[48866.03],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fill ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="83bd4e21-e9b8-4cf5-8c67-d6d5d8e08628" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83bd4e21-e9b8-4cf5-8c67-d6d5d8e08628")) {                    Plotly.newPlot(                        "83bd4e21-e9b8-4cf5-8c67-d6d5d8e08628",                        [{"alignmentgroup":"True","hovertemplate":"Product Category=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Ink","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Ink","offsetgroup":"Ink","orientation":"v","showlegend":true,"textposition":"auto","x":["Ink"],"xaxis":"x","y":[37128.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product Category=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Paper","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paper","offsetgroup":"Paper","orientation":"v","showlegend":true,"textposition":"auto","x":["Paper"],"xaxis":"x","y":[46175.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Product Category=%{x}<br>Total Amount=%{y}<extra></extra>","legendgroup":"Printer","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Printer","offsetgroup":"Printer","orientation":"v","showlegend":true,"textposition":"auto","x":["Printer"],"xaxis":"x","y":[60582.479999999996],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"co ...
